# %%
from mylib.lib import (
    load_dataset,
    process_mean,
    process_median,
    process_max,
    process_min,
    process_std,
    bar_visual,
    hist_visual
)

# %%
df = load_dataset()
assert df is not None
assert df.shape == (56, 8)
df.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14
# 0                      0                 0
# 1                      1                88
# 2                      0                 0
# 3                      0                 0
# 4                      0                 0

# %%
general_test = df.describe()

mean_test = process_mean(df, "incidents_85_99")
assert general_test.loc["mean", "incidents_85_99"] == mean_test

median_test = process_median(df, "fatal_accidents_85_99")
assert general_test.loc["50%", "fatal_accidents_85_99"] == median_test

max_test = process_max(df, "fatalities_85_99")
assert general_test.loc["max", "fatalities_85_99"] == max_test

min_test = process_min(df, "incidents_00_14")
assert general_test.loc["min", "incidents_00_14"] == min_test

std_test = process_std(df, "fatalities_00_14")
assert general_test.loc["std", "fatalities_00_14"] == std_test

# %%
hist_visual(df, "incidents_85_99", True)
hist_visual(df, "fatal_accidents_85_99", True)
hist_visual(df, "fatalities_85_99", True)
hist_visual(df, "incidents_00_14", True)
hist_visual(df, "fatal_accidents_00_14", True)
hist_visual(df, "fatalities_00_14", True)

# %%
bar_visual(df, "incidents_85_99", True)
bar_visual(df, "fatal_accidents_85_99", True)
bar_visual(df, "fatalities_85_99", True)
bar_visual(df, "incidents_00_14", True)
bar_visual(df, "fatal_accidents_00_14", True)
bar_visual(df, "fatalities_00_14", True)
